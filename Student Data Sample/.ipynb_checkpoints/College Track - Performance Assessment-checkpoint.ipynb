# %% [markdown]
# ### College Track - Data Analyst Skills Assessment
#
# Here is a look at the code that I used to analyze the data.  This is the organized, curated version of my original Jupyter notebook when I was experimenting with what I wanted to do.

# %%
#Import packages and load excel into DataFrame
import pandas as pd
from operator import itemgetter
#Tried using index_col=None to ignore first column because of duplicates.  Found out it is a currently unsolved issue in pd.read_excel
df = pd.read_excel('Skill Assessment Data.xlsx')

#Print more rows to see entirety of DataFrame
pd.options.display.max_rows = 100

# %%
df.shape
# Out:
# (49, 69)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Student to Student
# Data columns (total 69 columns):
# My friends want me to succeed.                                                                                      49 non-null object
# My best friends model responsible behavior.                                                                         49 non-null object
# Other people pick on and bully me.                                                                                  49 non-null object
# I am confident in new situations.                                                                                   49 non-null object
# My friends treat me with respect and kindness                                                                       49 non-null object
# I am good at making and keeping friends.                                                                            49 non-null object
# I feel safe at school.                                                                                              49 non-null object
# I am good at handling conflict.                                                                                     49 non-null object
# People generally like me.                                                                                           49 non-null object
# I can go to my family for support and advice.                                                                       49 non-null object
# I feel understood by my family.                                                                                     49 non-null object
# I receive a lot of love and support from my family members.                                                         49 non-null object
# My family models appropriate and responsible behavior.                                                              49 non-null object
# My family is supportive of me to follow my dreams and achieve a college education.                                  49 non-null object
# I am a positive person.                                                                                             49 non-null object
# I eat healthy, regular meals.                                                                                       49 non-null object
# I am comfortable expressing my feelings to others.                                                                  49 non-null object
# I have very few fears and am not easily scared.                                                                     49 non-null object
# I sleep well at night.                                                                                              49 non-null object
# My feelings do not overwhelm me.                                                                                    49 non-null object
# I feel good about myself.                                                                                           49 non-null object
# I think before I do things.                                                                                         49 non-null object
# I hardly ever lose my temper.                                                                                       49 non-null object
# I manage my stress easily.                                                                                          49 non-null object
# I hardly ever get sick, headaches or stomach aches.                                                                 49 non-null object
# I am optimistic about my future.                                                                                    49 non-null object
# I hardly ever get distracted and am able to concentrate well.                                                       49 non-null object
# I hardly ever worry about anything.                                                                                 49 non-null object
# I feel good about myself..1                                                                                         49 non-null object
# I take good care of myself and my body.                                                                             49 non-null object
# Sometimes I hurt or cut on myself.                                                                                  49 non-null object
# Sometimes I use use alcohol or drugs to manage my stress.                                                           49 non-null object
# Sometimes I feel like the world would be better off without me in it.                                               49 non-null object
# Sometimes I feel so stressed out that I don't know what to do.                                                      49 non-null object
# Sometimes I restrict my food intake or make myself throw up.                                                        49 non-null object
# Sometimes I take things that aren't mine                                                                            49 non-null object
# Sometimes I pick on other people or bully them.                                                                     49 non-null object
# Sometimes I don't tell the truth/lie or cheat.                                                                      49 non-null object
# When I'm upset, it takes me a long time to feel better.                                                             49 non-null object
# When I'm upset, I become embarrassed for feeling that way.                                                          49 non-null object
# When I’m upset, I become out of control.                                                                            49 non-null object
# When I’m upset, I have difficulty focusing on other things.                                                         49 non-null object
# I care about what I am feeling.                                                                                     49 non-null object
# I am confused about how I feel.                                                                                     49 non-null object
# When I’m upset, I believe there is nothing I can do to make myself feel better.                                     49 non-null object
# When I’m upset, I feel guilty for feeling that way.                                                                 49 non-null object
# When I’m upset, I lose control over my behavior.                                                                    49 non-null object
# When I’m upset, I have difficulty concentrating.                                                                    49 non-null object
# When I’m upset, I acknowledge my emotions.                                                                          49 non-null object
# I have difficulty making sense out of my feelings.                                                                  49 non-null object
# When I’m upset, I believe that I will end up feeling very depressed.                                                49 non-null object
# When I’m upset, I become irritated for feeling that way.                                                            49 non-null object
# When I’m upset, I have difficulty controlling my behavior.                                                          49 non-null object
# When I’m upset, I have difficulty getting work done.                                                                49 non-null object
# I pay attention to how I feel.                                                                                      49 non-null object
# I have no idea how I am feeling.                                                                                    49 non-null object
# I am usually on my own.                                                                                             49 non-null object
# I have one good friend or more.                                                                                     49 non-null object
# Other people my age generally like me.                                                                              49 non-null object
# Other people pick on me.                                                                                            49 non-null object
# I get along better with adults than people my age.                                                                  49 non-null object
# I try to be nice to other people.                                                                                   49 non-null object
# I usually share with others.                                                                                        49 non-null object
# I am helpful if someone is hurt, upset or feeling ill.                                                              49 non-null object
# I often volunteer to help others.                                                                                   49 non-null object
# In the last month, how often have you felt that you were unable to control the important things in your life?       49 non-null object
# In the last month, how often have you felt confident about your ability to handle your personal problems?           49 non-null object
# In the last month, how often have you felt that things were going your way?                                         49 non-null object
# In the last month, how often have you felt difficulties were piling up so high that you could not overcome them?    49 non-null object
# dtypes: object(69)
# memory usage: 26.8+ KB

# %%
df.head(10)
# Out:
#         My friends want me to succeed.  \
# Student                            yes
# Student                            yes
# Student                            yes
# Student                            yes
# Student                            yes
# Student                            yes
# Student                            yes
# Student                            yes
# Student                        yes, no
# Student                            yes
#
#         My best friends model responsible behavior.  \
# Student                                         yes
# Student                                         yes
# Student                                         yes
# Student                                         yes
# Student                                         yes
# Student                                         yes
# Student                                         yes
# Student                                         yes
# Student                                          no
# Student                                     yes, no
#
#         Other people pick on and bully me. I am confident in new situations.  \
# Student                                 no                               yes
# Student                                 no                               yes
# Student                                 no                               yes
# Student                                 no                               yes
# Student                                yes                                no
# Student                                 no                                no
# Student                                 no                               yes
# Student                                 no                                no
# Student                                 no                               yes
# Student                                 no                               yes
#
#         My friends treat me with respect and kindness  \
# Student                                           yes
# Student                                           yes
# Student                                           yes
# Student                                           yes
# Student                                           yes
# Student                                           yes
# Student                                           yes
# Student                                           yes
# Student                                           yes
# Student                                           yes
#
#         I am good at making and keeping friends. I feel safe at school.  \
# Student                                      yes                    yes
# Student                                      yes                    yes
# Student                                      yes                    yes
# Student                                      yes                    yes
# Student                                      yes                     no
# Student                                      yes                    yes
# Student                                      yes                    yes
# Student                                      yes                    yes
# Student                                      yes                    yes
# Student                                      yes                    yes
#
#         I am good at handling conflict. People generally like me.  \
# Student                             yes                       yes
# Student                             yes                       yes
# Student                             yes                       yes
# Student                             yes                       yes
# Student                             yes                       yes
# Student                             yes                       yes
# Student                             yes                       yes
# Student                             yes                       yes
# Student                             yes                       yes
# Student                             yes                       yes
#
#         I can go to my family for support and advice.  \
# Student                                           yes
# Student                                           yes
# Student                                           yes
# Student                                           yes
# Student                                            no
# Student                                           yes
# Student                                           yes
# Student                                       yes, no
# Student                                           yes
# Student                                           yes
#
#                                                               ...                                                         \
# Student                                                       ...
# Student                                                       ...
# Student                                                       ...
# Student                                                       ...
# Student                                                       ...
# Student                                                       ...
# Student                                                       ...
# Student                                                       ...
# Student                                                       ...
# Student                                                       ...
#
#         Other people pick on me.  \
# Student                 Not true
# Student                 Not true
# Student                 Not true
# Student                 Not true
# Student            Somewhat true
# Student                 Not true
# Student                 Not true
# Student                 Not true
# Student                 Not true
# Student                 Not true
#
#         I get along better with adults than people my age.  \
# Student                                           Not true
# Student                                      Somewhat true
# Student                                      Somewhat true
# Student                                      Somewhat true
# Student                                      Somewhat true
# Student                                      Somewhat true
# Student                                           Not true
# Student                                      Somewhat true
# Student                                      Somewhat true
# Student                                           Not true
#
#         I try to be nice to other people. I usually share with others.  \
# Student                    Certainly true                Somewhat true
# Student                    Certainly true               Certainly true
# Student                    Certainly true                Somewhat true
# Student                    Certainly true                Somewhat true
# Student                    Certainly true               Certainly true
# Student                    Certainly true                Somewhat true
# Student                    Certainly true               Certainly true
# Student                    Certainly true                Somewhat true
# Student                     Somewhat true                Somewhat true
# Student                    Certainly true                Somewhat true
#
#         I am helpful if someone is hurt, upset or feeling ill.  \
# Student                                     Certainly true
# Student                                     Certainly true
# Student                                     Certainly true
# Student                                     Certainly true
# Student                                     Certainly true
# Student                                     Certainly true
# Student                                     Certainly true
# Student                                     Certainly true
# Student                                      Somewhat true
# Student                                      Somewhat true
#
#         I often volunteer to help others.  \
# Student                     Somewhat true
# Student                    Certainly true
# Student                    Certainly true
# Student                     Somewhat true
# Student                    Certainly true
# Student                    Certainly true
# Student                    Certainly true
# Student                    Certainly true
# Student                     Somewhat true
# Student                     Somewhat true
#
#         In the last month, how often have you felt that you were unable to control the important things in your life?  \
# Student                                       almost never
# Student                                       almost never
# Student                                              never
# Student                                              never
# Student                                          sometimes
# Student                                              never
# Student                                          sometimes
# Student                                       almost never
# Student                                       almost never
# Student                                              never
#
#         In the last month, how often have you felt confident about your ability to handle your personal problems?  \
# Student                                       fairly often
# Student                                       fairly often
# Student                                              often
# Student                                              often
# Student                                       almost never
# Student                                              often
# Student                                       fairly often
# Student                                       fairly often
# Student                                       almost never
# Student                                       fairly often
#
#         In the last month, how often have you felt that things were going your way?  \
# Student                                       fairly often
# Student                                       fairly often
# Student                                       fairly often
# Student                                          sometimes
# Student                                              never
# Student                                          sometimes
# Student                                       fairly often
# Student                                          sometimes
# Student                                       almost never
# Student                                       fairly often
#
#         In the last month, how often have you felt difficulties were piling up so high that you could not overcome them?
# Student                                       almost never
# Student                                       almost never
# Student                                              never
# Student                                              never
# Student                                       fairly often
# Student                                          sometimes
# Student                                       fairly often
# Student                                       almost never
# Student                                       almost never
# Student                                              never
#
# [10 rows x 69 columns]

# %%
#Search for all incidents of yes, no responses and replace with unsure
for col in df.columns:
    df.loc[df[col].str.contains(','), col] = 'unsure'

# %%
#Adding number to student in index to keep track of individual student responses
df.reset_index(inplace=True)

for i in range(len(df)):
    df.iloc[i,0] = ('Student ' + str(i))

df.set_index('index', inplace=True)

# %%
#Function to report percentages of most common response for each statement.
#Optional arguments to include questions with a specific word and drop the column from the DataFrame
def results_search(df, word='', drop_col=False):
    #Initialize empty list 
    li=[]

    data=df.loc[:, df.columns.str.contains(word)]

    #Calculating the percentage
    for statement in data.columns:
        count = data[statement].value_counts()
        results = round(count.max()/count.sum(), 3)

        #Appending to empty list to create list containing results for all questions/statements from survey
        li.append([statement, results, count])

    #Ordering list based on the 2nd element (results) of each question/statement
    ordered_li = sorted(li, key=itemgetter(1), reverse=True)

    #Attempting to print in an easier to read format.
    for entry in ordered_li:
        print('-----------------------------','\n')
        for element in entry:
            print(element)

    #Remove columns from original dataframe to reduce size (defaults to False)
    df.drop(data.columns, axis=1, inplace=drop_col)

# %% [markdown]
# At this point, I started searching use a variety of keywords.  I didn't drop the questions in the beginning, but spent some time searching for various common terms you would expect in a social-emotional well-being survey.  The ones you see below are the ones that I included in my report.

# %%
results_search(df, 'family', drop_col=True)
# Out:
# -----------------------------
#
# My family is supportive of me to follow my dreams and achieve a college education.
# 1.0
# yes    49
# Name: My family is supportive of me to follow my dreams and achieve a college education., dtype: int64
# -----------------------------
#
# I receive a lot of love and support from my family members.
# 0.898
# yes       44
# no         3
# unsure     2
# Name: I receive a lot of love and support from my family members., dtype: int64
# -----------------------------
#
# My family models appropriate and responsible behavior.
# 0.878
# yes       43
# unsure     4
# no         2
# Name: My family models appropriate and responsible behavior., dtype: int64
# -----------------------------
#
# I can go to my family for support and advice.
# 0.776
# yes       38
# no         8
# unsure     3
# Name: I can go to my family for support and advice., dtype: int64
# -----------------------------
#
# I feel understood by my family.
# 0.673
# yes       33
# no        14
# unsure     2
# Name: I feel understood by my family., dtype: int64

# %%
results_search(df,'friends', drop_col=True)
# Out:
# -----------------------------
#
# My friends want me to succeed.
# 0.939
# yes       46
# unsure     3
# Name: My friends want me to succeed., dtype: int64
# -----------------------------
#
# My friends treat me with respect and kindness
# 0.939
# yes       46
# no         2
# unsure     1
# Name: My friends treat me with respect and kindness, dtype: int64
# -----------------------------
#
# I am good at making and keeping friends.
# 0.878
# yes       43
# no         5
# unsure     1
# Name: I am good at making and keeping friends., dtype: int64
# -----------------------------
#
# My best friends model responsible behavior.
# 0.796
# yes       39
# no         6
# unsure     4
# Name: My best friends model responsible behavior., dtype: int64

# %%
results_search(df, 'stress', drop_col=True)
# Out:
# -----------------------------
#
# Sometimes I use use alcohol or drugs to manage my stress.
# 0.959
# no     47
# yes     2
# Name: Sometimes I use use alcohol or drugs to manage my stress., dtype: int64
# -----------------------------
#
# I manage my stress easily.
# 0.633
# yes       31
# no        15
# unsure     3
# Name: I manage my stress easily., dtype: int64
# -----------------------------
#
# Sometimes I feel so stressed out that I don't know what to do.
# 0.592
# yes    29
# no     20
# Name: Sometimes I feel so stressed out that I don't know what to do., dtype: int64

# %%
results_search(df, 'emotion', drop_col=True)
# Out:
# -----------------------------
#
# When I’m upset, I acknowledge my emotions.
# 0.265
# most of the time       13
# sometimes              12
# about half the time    11
# almost never            8
# almost always           5
# Name: When I’m upset, I acknowledge my emotions., dtype: int64

# %%
results_search(df, 'upset', drop_col=True)
# Out:
# -----------------------------
#
# When I’m upset, I become out of control.
# 0.816
# almost never           40
# sometimes               5
# about half the time     2
# most of the time        2
# Name: When I’m upset, I become out of control., dtype: int64
# -----------------------------
#
# When I’m upset, I lose control over my behavior.
# 0.796
# almost never           39
# sometimes               8
# about half the time     1
# most of the time        1
# Name: When I’m upset, I lose control over my behavior., dtype: int64
# -----------------------------
#
# I am helpful if someone is hurt, upset or feeling ill.
# 0.776
# Certainly true    38
# Somewhat true     11
# Name: I am helpful if someone is hurt, upset or feeling ill., dtype: int64
# -----------------------------
#
# When I’m upset, I have difficulty controlling my behavior.
# 0.735
# almost never           36
# sometimes              10
# about half the time     2
# almost always           1
# Name: When I’m upset, I have difficulty controlling my behavior., dtype: int64
# -----------------------------
#
# When I’m upset, I feel guilty for feeling that way.
# 0.653
# almost never           32
# sometimes              13
# about half the time     3
# most of the time        1
# Name: When I’m upset, I feel guilty for feeling that way., dtype: int64
# -----------------------------
#
# When I’m upset, I believe there is nothing I can do to make myself feel better.
# 0.571
# almost never           28
# sometimes              16
# about half the time     3
# almost always           1
# most of the time        1
# Name: When I’m upset, I believe there is nothing I can do to make myself feel better., dtype: int64
# -----------------------------
#
# When I’m upset, I believe that I will end up feeling very depressed.
# 0.551
# almost never           27
# sometimes              14
# about half the time     4
# most of the time        3
# almost always           1
# Name: When I’m upset, I believe that I will end up feeling very depressed., dtype: int64
# -----------------------------
#
# When I'm upset, I become embarrassed for feeling that way.
# 0.49
# almost never           24
# sometimes              14
# about half the time     6
# most of the time        5
# Name: When I'm upset, I become embarrassed for feeling that way., dtype: int64
# -----------------------------
#
# When I'm upset, it takes me a long time to feel better.
# 0.469
# sometimes              23
# almost never           13
# about half the time     9
# most of the time        2
# almost always           2
# Name: When I'm upset, it takes me a long time to feel better., dtype: int64
# -----------------------------
#
# When I’m upset, I have difficulty concentrating.
# 0.408
# sometimes              20
# most of the time       13
# almost never            7
# about half the time     7
# almost always           2
# Name: When I’m upset, I have difficulty concentrating., dtype: int64
# -----------------------------
#
# When I’m upset, I become irritated for feeling that way.
# 0.388
# sometimes              19
# almost never           15
# about half the time    10
# most of the time        3
# almost always           2
# Name: When I’m upset, I become irritated for feeling that way., dtype: int64
# -----------------------------
#
# When I’m upset, I have difficulty getting work done.
# 0.367
# sometimes              18
# almost never           12
# about half the time     9
# most of the time        8
# almost always           2
# Name: When I’m upset, I have difficulty getting work done., dtype: int64
# -----------------------------
#
# When I’m upset, I have difficulty focusing on other things.
# 0.347
# sometimes              17
# about half the time    11
# almost never            9
# most of the time        8
# almost always           4
# Name: When I’m upset, I have difficulty focusing on other things., dtype: int64

# %% [markdown]
# At this point, I went back to looking at the remaining questions all at once, as there didn't seem to be any great keywords that I could use to search anymore.

# %%
results_search(df)
# Out:
# -----------------------------
#
# People generally like me.
# 0.959
# yes       47
# unsure     1
# no         1
# Name: People generally like me., dtype: int64
# -----------------------------
#
# I am optimistic about my future.
# 0.959
# yes    47
# no      2
# Name: I am optimistic about my future., dtype: int64
# -----------------------------
#
# Sometimes I hurt or cut on myself.
# 0.959
# no     47
# yes     2
# Name: Sometimes I hurt or cut on myself., dtype: int64
# -----------------------------
#
# I feel safe at school.
# 0.939
# yes       46
# unsure     2
# no         1
# Name: I feel safe at school., dtype: int64
# -----------------------------
#
# I am a positive person.
# 0.939
# yes       46
# unsure     3
# Name: I am a positive person., dtype: int64
# -----------------------------
#
# Sometimes I pick on other people or bully them.
# 0.939
# no        46
# unsure     2
# yes        1
# Name: Sometimes I pick on other people or bully them., dtype: int64
# -----------------------------
#
# Sometimes I restrict my food intake or make myself throw up.
# 0.918
# no     45
# yes     4
# Name: Sometimes I restrict my food intake or make myself throw up., dtype: int64
# -----------------------------
#
# I take good care of myself and my body.
# 0.898
# yes       44
# no         4
# unsure     1
# Name: I take good care of myself and my body., dtype: int64
# -----------------------------
#
# I feel good about myself..1
# 0.878
# yes       43
# no         5
# unsure     1
# Name: I feel good about myself..1, dtype: int64
# -----------------------------
#
# Sometimes I take things that aren't mine
# 0.878
# no        43
# yes        5
# unsure     1
# Name: Sometimes I take things that aren't mine, dtype: int64
# -----------------------------
#
# I try to be nice to other people.
# 0.878
# Certainly true    43
# Somewhat true      5
# Not true           1
# Name: I try to be nice to other people., dtype: int64
# -----------------------------
#
# Other people pick on and bully me.
# 0.857
# no        42
# yes        6
# unsure     1
# Name: Other people pick on and bully me., dtype: int64
# -----------------------------
#
# I feel good about myself.
# 0.857
# yes       42
# no         4
# unsure     3
# Name: I feel good about myself., dtype: int64
# -----------------------------
#
# Sometimes I feel like the world would be better off without me in it.
# 0.857
# no        42
# yes        6
# unsure     1
# Name: Sometimes I feel like the world would be better off without me in it., dtype: int64
# -----------------------------
#
# I think before I do things.
# 0.837
# yes       41
# no         6
# unsure     2
# Name: I think before I do things., dtype: int64
# -----------------------------
#
# I have one good friend or more.
# 0.816
# Certainly true    40
# Somewhat true      6
# Not true           3
# Name: I have one good friend or more., dtype: int64
# -----------------------------
#
# I hardly ever lose my temper.
# 0.796
# yes       39
# no         9
# unsure     1
# Name: I hardly ever lose my temper., dtype: int64
# -----------------------------
#
# I am good at handling conflict.
# 0.776
# yes    38
# no     11
# Name: I am good at handling conflict., dtype: int64
# -----------------------------
#
# I eat healthy, regular meals.
# 0.755
# yes       37
# no        10
# unsure     2
# Name: I eat healthy, regular meals., dtype: int64
# -----------------------------
#
# Other people pick on me.
# 0.735
# Not true          36
# Somewhat true     11
# Certainly true     2
# Name: Other people pick on me., dtype: int64
# -----------------------------
#
# I hardly ever worry about anything.
# 0.714
# no        35
# yes       13
# unsure     1
# Name: I hardly ever worry about anything., dtype: int64
# -----------------------------
#
# I hardly ever get distracted and am able to concentrate well.
# 0.673
# no        33
# yes       15
# unsure     1
# Name: I hardly ever get distracted and am able to concentrate well., dtype: int64
# -----------------------------
#
# I sleep well at night.
# 0.653
# yes       32
# no        14
# unsure     3
# Name: I sleep well at night., dtype: int64
# -----------------------------
#
# I hardly ever get sick, headaches or stomach aches.
# 0.633
# yes       31
# no        15
# unsure     3
# Name: I hardly ever get sick, headaches or stomach aches., dtype: int64
# -----------------------------
#
# I usually share with others.
# 0.612
# Certainly true    30
# Somewhat true     19
# Name: I usually share with others., dtype: int64
# -----------------------------
#
# I get along better with adults than people my age.
# 0.592
# Somewhat true     29
# Not true          13
# Certainly true     7
# Name: I get along better with adults than people my age., dtype: int64
# -----------------------------
#
# I am confident in new situations.
# 0.571
# yes       28
# no        20
# unsure     1
# Name: I am confident in new situations., dtype: int64
# -----------------------------
#
# Sometimes I don't tell the truth/lie or cheat.
# 0.571
# no        28
# yes       20
# unsure     1
# Name: Sometimes I don't tell the truth/lie or cheat., dtype: int64
# -----------------------------
#
# I often volunteer to help others.
# 0.571
# Certainly true    28
# Somewhat true     21
# Name: I often volunteer to help others., dtype: int64
# -----------------------------
#
# I have very few fears and am not easily scared.
# 0.551
# no     27
# yes    22
# Name: I have very few fears and am not easily scared., dtype: int64
# -----------------------------
#
# I am comfortable expressing my feelings to others.
# 0.531
# yes       26
# no        21
# unsure     2
# Name: I am comfortable expressing my feelings to others., dtype: int64
# -----------------------------
#
# I am confused about how I feel.
# 0.531
# almost never           26
# sometimes              13
# about half the time     7
# most of the time        2
# almost always           1
# Name: I am confused about how I feel., dtype: int64
# -----------------------------
#
# Other people my age generally like me.
# 0.531
# Certainly true    26
# Somewhat true     21
# Not true           2
# Name: Other people my age generally like me., dtype: int64
# -----------------------------
#
# My feelings do not overwhelm me.
# 0.51
# yes       25
# no        20
# unsure     4
# Name: My feelings do not overwhelm me., dtype: int64
# -----------------------------
#
# I have difficulty making sense out of my feelings.
# 0.469
# almost never           23
# sometimes              17
# about half the time     5
# most of the time        3
# almost always           1
# Name: I have difficulty making sense out of my feelings., dtype: int64
# -----------------------------
#
# I am usually on my own.
# 0.469
# Not true          23
# Somewhat true     22
# Certainly true     4
# Name: I am usually on my own., dtype: int64
# -----------------------------
#
# I care about what I am feeling.
# 0.408
# most of the time       20
# almost always          12
# sometimes               8
# about half the time     5
# almost never            4
# Name: I care about what I am feeling., dtype: int64
# -----------------------------
#
# I have no idea how I am feeling.
# 0.408
# sometimes              20
# almost never           19
# about half the time     5
# almost always           3
# most of the time        2
# Name: I have no idea how I am feeling., dtype: int64
# -----------------------------
#
# In the last month, how often have you felt that things were going your way?
# 0.408
# fairly often    20
# sometimes       18
# never            4
# almost never     4
# often            3
# Name: In the last month, how often have you felt that things were going your way?, dtype: int64
# -----------------------------
#
# In the last month, how often have you felt difficulties were piling up so high that you could not overcome them?
# 0.367
# almost never    18
# sometimes       12
# never           10
# fairly often     7
# often            2
# Name: In the last month, how often have you felt difficulties were piling up so high that you could not overcome them?, dtype: int64
# -----------------------------
#
# I pay attention to how I feel.
# 0.347
# sometimes              17
# most of the time       13
# almost always           9
# about half the time     6
# almost never            4
# Name: I pay attention to how I feel., dtype: int64
# -----------------------------
#
# In the last month, how often have you felt that you were unable to control the important things in your life?
# 0.327
# almost never    16
# sometimes       16
# never           11
# fairly often     6
# Name: In the last month, how often have you felt that you were unable to control the important things in your life?, dtype: int64
# -----------------------------
#
# In the last month, how often have you felt confident about your ability to handle your personal problems?
# 0.306
# sometimes       15
# fairly often    14
# often           10
# almost never     8
# never            2
# Name: In the last month, how often have you felt confident about your ability to handle your personal problems?, dtype: int64

# %%
#Searching for students in potential crisis
df.loc[(df['Sometimes I hurt or cut on myself.']=='yes') |
      (df['Sometimes I restrict my food intake or make myself throw up.']=='yes') |
      (df['Sometimes I feel like the world would be better off without me in it.']=='yes'),
      ['Sometimes I hurt or cut on myself.', 
       'Sometimes I restrict my food intake or make myself throw up.', 
       'Sometimes I feel like the world would be better off without me in it.']
      ].T
# Out:
# index                                              Student 16 Student 20  \
# Sometimes I hurt or cut on myself.                        yes         no
# Sometimes I restrict my food intake or make mys...        yes         no
# Sometimes I feel like the world would be better...         no        yes
#
# index                                              Student 31 Student 32  \
# Sometimes I hurt or cut on myself.                         no         no
# Sometimes I restrict my food intake or make mys...         no        yes
# Sometimes I feel like the world would be better...        yes        yes
#
# index                                              Student 36 Student 37  \
# Sometimes I hurt or cut on myself.                         no        yes
# Sometimes I restrict my food intake or make mys...         no         no
# Sometimes I feel like the world would be better...        yes        yes
#
# index                                              Student 41 Student 45
# Sometimes I hurt or cut on myself.                         no         no
# Sometimes I restrict my food intake or make mys...        yes        yes
# Sometimes I feel like the world would be better...         no        yes
